# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from crypto_chatter.data.load_raw_data import load_raw_data
from crypto_chatter.graph import CryptoTwitterReplyGraph
from crypto_chatter.config import (
    ES_TWITTER_QUERY,
    ES_HOSTNAME,
    ES_TWITTER_COLUMNS,
    ES_TWITTER_MAPPINGS,
    ES_TWITTER_KEYWORDS,
    DATA_DIR,
    CryptoChatterDataConfig,
)
import networkx as nx

# %%
data_source = 'twitter'
index_name = 'blockchain-interoperability-attacks'

es_query = ES_TWITTER_QUERY
es_query['query']['bool']['must'] = {
    "simple_query_string": {
        "query": ' '.join(ES_TWITTER_KEYWORDS),
        "fields": [
            "text",
            "extended_tweet.full_text"
        ],
    }
}

data_config = CryptoChatterDataConfig(
            es_hostname=ES_HOSTNAME,
            es_index=index_name,
            es_columns=ES_TWITTER_COLUMNS,
            es_mappings=ES_TWITTER_MAPPINGS,
            es_query=es_query,
            data_source=data_source,
            node_id_col='id',
            raw_snapshot_dir = DATA_DIR / f'twitter/{index_name}/snapshots',
            graph_dir = DATA_DIR / f'twitter/{index_name}/graph',
            graph_gephi_dir = DATA_DIR / f'twitter/{index_name}/graph/gephi',
            graph_components_dir = DATA_DIR / f'twitter/{index_name}/graph/components',
            graph_stats_file = DATA_DIR / f'twitter/{index_name}/graph/stats.json',
            graph_edges_file = DATA_DIR / f'twitter/{index_name}/graph/edges.json',
            graph_nodes_file = DATA_DIR / f'twitter/{index_name}/graph/nodes.json',
            graph_data_file = DATA_DIR / f'twitter/{index_name}/graph/graph_data.pkl',
            graph_attributes = ['full_text', 'user.id', 'user.followers_count', 'favorite_count', 'quote_count'],
        )
data_config.raw_snapshot_dir.mkdir(parents=True, exist_ok=True)
data_config.graph_dir.mkdir(parents=True, exist_ok=True)
data_config.graph_components_dir.mkdir(parents=True, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 34
#      15 data_config = CryptoChatterDataConfig(
#      16             es_hostname=ES_HOSTNAME,
#      17             es_index=index_name,
#    (...)
#      31             graph_attributes = ['full_text', 'user.id', 'user.followers_count', 'favorite_count', 'quote_count'],
#      32         )
#      33 data_config.raw_snapshot_dir.mkdir(parents=True, exist_ok=True)
# ---> 34 data_config.graph_dir.mkdir(parents=True, exist_ok=True)
#      35 data_config.graph_components_dir.mkdir(parents=True, exist_ok=True)
#
# File ~/miniconda3/envs/contenv/lib/python3.10/pathlib.py:1175, in Path.mkdir(self, mode, parents, exist_ok)
#    1171 """
#    1172 Create a new directory at this given path.
#    1173 """
#    1174 try:
# -> 1175     self._accessor.mkdir(self, mode)
#    1176 except FileNotFoundError:
#    1177     if not parents or self.parent == self:
#
# PermissionError: [Errno 13] Permission denied: '/Users/mridul/Desktop/TwitterAnalysis/data/mridul/twitter_data/twitter/blockchain-interoperability-attacks/graph'

# %%
df = load_raw_data(data_config)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Loaded cache in 127 seconds

# %%
df.head(10)
# Out:
#                        created_at  \
# 0  Fri Nov 11 12:03:53 +0000 2022
# 1  Fri Nov 11 12:03:53 +0000 2022
# 2  Fri Nov 11 12:03:53 +0000 2022
# 3  Fri Nov 11 12:03:54 +0000 2022
# 4  Fri Nov 11 12:03:54 +0000 2022
# 5  Fri Nov 11 12:03:54 +0000 2022
# 6  Fri Nov 11 12:03:54 +0000 2022
# 7  Fri Nov 11 12:03:54 +0000 2022
# 8  Fri Nov 11 12:03:54 +0000 2022
# 9  Fri Nov 11 12:03:54 +0000 2022
#
#                             extended_tweet.full_text  favorite_count  \
# 0                                                NaN               0
# 1  Never seen such a deal for a punk since 2017! ...               0
# 2  Collection: ens \n Sold for: 1.0040189 Eth (12...               0
# 3  @Rocket_Moonshot @NzXrp @Bitboy_Crypto @digita...               0
# 4  @abu_crypto1 🩸 Scary bunny is a meme token wit...               0
# 5  We on it fam! 🦾 @Zibex13Zibex @SushmaPatel13 @...               0
# 6  @mishaboar @boni83737812 I Wish I discovered t...               0
# 7  token Status!? still going?? $APTOS @hanrris98...               0
# 8                                                NaN               0
# 9                                                NaN               0
#
#                                            full_text  geo geo.coordinates  \
# 0  @0x5ab0 @Uniswap oh, missed fiat part, just sa...  NaN             NaN
# 1  Never seen such a deal for a punk since 2017! ...  NaN             NaN
# 2  Collection: ens \n Sold for: 1.0040189 Eth (12...  NaN             NaN
# 3  @Rocket_Moonshot @NzXrp @Bitboy_Crypto @digita...  NaN             NaN
# 4  @abu_crypto1 🩸 Scary bunny is a meme token wit...  NaN             NaN
# 5  We on it fam! 🦾 @Zibex13Zibex @SushmaPatel13 @...  NaN             NaN
# 6  @mishaboar @boni83737812 I Wish I discovered t...  NaN             NaN
# 7  token Status!? still going?? $APTOS @hanrris98...  NaN             NaN
# 8  I really need to learn how to dev on blockchai...  NaN             NaN
# 9  @RetirementRight Clearly you don't understand ...  NaN             NaN
#
#   geo.type                   id  quote_count        quoted_status.created_at  \
# 0      NaN  1591039006850310148            0                             NaN
# 1      NaN  1591039006770622468            0  Fri Nov 11 11:00:59 +0000 2022
# 2      NaN  1591039006501994503            0                             NaN
# 3      NaN  1591039007357550592            0                             NaN
# 4      NaN  1591039007764668417            0                             NaN
# 5      NaN  1591039007827595264            0  Fri Nov 11 05:26:44 +0000 2022
# 6      NaN  1591039008205070336            0                             NaN
# 7      NaN  1591039008406020097            0  Fri Nov 11 05:26:44 +0000 2022
# 8      NaN  1591039008800641025            0  Fri Nov 11 11:30:06 +0000 2022
# 9      NaN  1591039008930689024            0                             NaN
#
#    ... truncated  truncatedquoted_status.truncated  \
# 0  ...     False                               NaN
# 1  ...      True                               NaN
# 2  ...      True                               NaN
# 3  ...      True                               NaN
# 4  ...      True                               NaN
# 5  ...      True                               NaN
# 6  ...      True                               NaN
# 7  ...      True                               NaN
# 8  ...     False                               NaN
# 9  ...     False                               NaN
#
#                   user.created_at  user.followers_count  user.friends_count  \
# 0  Mon Jul 11 06:36:43 +0000 2011                  7050                5554
# 1  Wed Nov 09 14:09:46 +0000 2022                     0                   2
# 2  Sun May 01 15:06:34 +0000 2022                   106                   2
# 3  Wed Dec 18 21:46:55 +0000 2013                     0                   0
# 4  Tue Oct 25 03:46:04 +0000 2022                     3                  50
# 5  Sun Nov 06 15:43:41 +0000 2022                     0                   3
# 6  Tue Dec 17 09:02:37 +0000 2013                     0                   1
# 7  Tue Nov 01 23:12:50 +0000 2022                     0                   2
# 8  Thu Nov 11 10:47:29 +0000 2021                   198                 689
# 9  Thu Apr 15 17:45:25 +0000 2021                    93                 524
#
#    user.geo_enabled              user.id              user.location  \
# 0              True            333239871             CARBONdale, CO
# 1             False  1590345908172083201                Netherlands
# 2             False  1520781667769614337                 blockchain
# 3             False           2252580014                       None
# 4             False  1584753080113025025                       None
# 5             False  1589282375837650944               Sierra Leone
# 6             False           2250097452                       None
# 7             False  1587583470859161601  Bonaire, Sint Eustatius a
# 8             False  1458748164635181060                banjarmasin
# 9             False  1382751867868942337                       None
#
#   quoted_status.geo.coordinates  quoted_status.geo.type
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# 5                           NaN                     NaN
# 6                           NaN                     NaN
# 7                           NaN                     NaN
# 8                           NaN                     NaN
# 9                           NaN                     NaN
#
# [10 rows x 39 columns]

# %%
len(df)
# Out:
# 16625047

# %%
df.columns
# Out:
# Index(['created_at', 'extended_tweet.full_text', 'favorite_count', 'full_text',
#        'geo', 'geo.coordinates', 'geo.type', 'id', 'quote_count',
#        'quoted_status.created_at', 'quoted_status.extended_tweet.full_text',
#        'quoted_status.favorite_count', 'quoted_status.full_text',
#        'quoted_status.geo', 'quoted_status.id', 'quoted_status.quote_count',
#        'quoted_status.reply_count', 'quoted_status.retweet_count',
#        'quoted_status.text', 'quoted_status.truncated',
#        'quoted_status.user.created_at', 'quoted_status.user.followers_count',
#        'quoted_status.user.friends_count', 'quoted_status.user.geo_enabled',
#        'quoted_status.user.id', 'quoted_status.user.location', 'reply_count',
#        'retweet_count', 'text', 'truncated',
#        'truncatedquoted_status.truncated', 'user.created_at',
#        'user.followers_count', 'user.friends_count', 'user.geo_enabled',
#        'user.id', 'user.location', 'quoted_status.geo.coordinates',
#        'quoted_status.geo.type'],
#       dtype='object')

# %%
user_id_frequency = df['user.id'].value_counts()
user_id_frequency = user_id_frequency.sort_values(ascending=False)

# %%
top = 10000
top_freqs = user_id_frequency.head(top)
top_freqs
# Out:
# user.id
# 1518863995662389248    27082
# 1551067188882116608    19363
# 1501922448324927500    16546
# 1569120919356084225    15792
# 1551237890302156802    12750
#                        ...
# 911613514137182208       152
# 1585811791501983744      152
# 1239641591561752576      152
# 1482217961255731200      152
# 1462071840               152
# Name: count, Length: 10000, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.plot(top_freqs.values, linestyle='-', marker='o')
plt.title('Top ' + str(top) + ' User IDs vs Row Frequency')
plt.xlabel('Row Index')
plt.ylabel('Row Frequency')
plt.yticks(range(0, max(top_freqs), 2000))  # Adjust the step as needed
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(12, 6))
#       2 plt.plot(top_freqs.values, linestyle='-', marker='o')
#       3 plt.title('Top ' + str(top) + ' User IDs vs Row Frequency')
#
# NameError: name 'plt' is not defined

# %%
user_id_frequency.head(10)
# Out:
# user.id
# 1518863995662389248    27082
# 1551067188882116608    19363
# 1501922448324927500    16546
# 1569120919356084225    15792
# 1551237890302156802    12750
# 1462970957061107712    12720
# 1548018226189086720    12023
# 1520781667769614337    11907
# 922928836836130816     11123
# 1495015555283120130    10698
# Name: count, dtype: int64

# %%
N = 10

tweet_samples = []

for uid in user_id_frequency.head(N).index:
    freq = user_id_frequency[uid]
    tweet = df[df['user.id'] == uid]['full_text'].values[0]
    tweet_samples.append({'User_ID': uid, 'Frequency': freq, 'Full_Text': tweet})
    
pd.set_option('display.max_colwidth', 120)
tweet_samples = pd.DataFrame(tweet_samples)

tweet_samples
# Out:
#                User_ID  Frequency  \
# 0  1518863995662389248      27082
# 1  1551067188882116608      19363
# 2  1501922448324927500      16546
# 3  1569120919356084225      15792
# 4  1551237890302156802      12750
# 5  1462970957061107712      12720
# 6  1548018226189086720      12023
# 7  1520781667769614337      11907
# 8   922928836836130816      11123
# 9  1495015555283120130      10698
#
#                                                                                                                  Full_Text
# 0  @thisuserh Your screenshot can be found below 😁!\n\n🤩Ad: This Crypto project SAFCOIN1 has grown by 500% despite the ...
# 1  #Ethereum price update: \n\n#ETH $1278.96 USD\n#Bitcoin 0.07359387569323687 #BTC\n\nFollow for recent ETH price upda...
# 2  #Binance Last Price $296 #BNB 🚀\nDaily Indicators:\n-RSI: 47.2\n-Moving Average(20): 310\n-MA(50): 290\n-MA(200): 28...
# 3  $256.37k #BTC bought at $17365.1 (USDT) on Binance Spot.\n\n#BTC $BTC #crypto #whale #alert\nFor real-time Whale ins...
# 4  #BSCGems #BNB #Crypto #BSCGemsAlert #altcoins #Binance #100x\n28 days, 16:54:56\n\nTell Them Joe Coin Sent you\n 👀👀 ...
# 5  #BSCGems #BNB #Crypto #BSCGemsAlert #altcoins #Binance #100x\n28 days, 16:54:36\n\nTell Them Joe Coin Sent you\n 👀👀 ...
# 6  #BSCGems #BNB #Crypto #BSCGemsAlert #altcoins #Binance #100x\n28 days, 16:54:38\n\nTell Them Joe Coin Sent you\n 👀👀 ...
# 7  Collection: ens \n Sold for: 1.0040189 Eth (1282.965470987 USD) \n Seller:0x5654967dc2c3f207b68bbd8003bc27a0a4106b56...
# 8  @bello_wrld Autobots, Roll out! Claim your #EarthSparkPizzaNight 🍕 prize here https://t.co/5I6eJJppc3 . Stream @Nick...
# 9  #BCHUSDT Bear Alert!\n\n5X Volume\nPrice:      105.1\n5-min %: 0.0%\nVolume:  $167,753\n \n#crypto #whale #btc #eth ...

# %%
ind = 50000
user_id_frequency.iloc[ind]
df[df['user.id'] == user_id_frequency.index[ind]]['full_text'].values[0]
# Out:
# 'Online class homework, assignment and exam expert help with\n\nPublic Administration\nAccounting and Financial Management\nDental Technology\nEnvironmental Studies\nGeomatics &amp; Geospatial Information Systems(#Geomatics)\nApplied Statistics with Programming\nCriminology, Security Studies'

# %%
retweets = df[['id', 'retweet_count', 'full_text', 'user.id']].sort_values(by='retweet_count', ascending=False)
retweets = retweets.reset_index(drop=True)

# %%
retweets.head(20)
# Out:
#                      id  retweet_count  \
# 0   1594764842220617728         167677
# 1   1592881058537648129         135855
# 2   1590359451353067520          41810
# 3   1594674635311824898          38973
# 4   1594632582230347777          37828
# 5   1587997517639294976          36181
# 6   1593182155647029253          34988
# 7   1591348321116749825          29231
# 8   1594721724746338305          26910
# 9   1591543049339174912          25305
# 10  1592547257496539137          24763
# 11  1590324375844458499          22143
# 12  1590480221257359361          21922
# 13  1592205858934607873          21838
# 14  1587527513953415168          21669
# 15  1588246302189838337          21627
# 16  1591600399118913536          20705
# 17  1588857768588738565          19894
# 18  1590839330201014273          19320
# 19  1591625254044041224          19193
#
#                                                                                                                   full_text  \
# 0   As a Qatari I’m proud of what happened. \nI don’t know when will the westerners realize that their values aren’t uni...
# 1   We’re excited to share, we have:\n\n1) Raised $200M and now have a total of $458M in mission-driven funding\n2) Deci...
# 2   Ground Control to Major Dog: we’re excited to announce DOGyssey, an adventure that rewards Tally Ho users for explor...
# 3   DAO Maker is a proud launch partner for the #TrustWalletExtension! To celebrate, everyone who completes the steps be...
# 4   DAO Maker is pleased to announce a giveway in partnership with Trust Wallet !\n\nWe’re giving away $2,000 in $TWT be...
# 5   Senator Mike Lee caught ON TAPE saying he wants to "phase out Social Security, pull it up from the roots, get rid of...
# 6   ⚽WinGoal $MLS Airdrops start NOW!🔥🔥\n\n💰13,100 Winners share 80,000 $MLS, TOP 100 get more rewards!💰\n\n⏰End Time: 1...
# 7                       🎙️ Abdullah Al Nasari, Head of Security at the World Cup in Qatar... 🏳️‍🌈🇶🇦 https://t.co/gDnJfnmnrd
# 8   Just now: Security guard refusing to let me into the stadium for USA-Wales. “You have to change your shirt. It’s not...
# 9                                       Motion activated home security camera working as intended.. https://t.co/T0XayfPYeu
# 10  Security Guard is a hero after taking down a suspect that entered a substance abuse treatment facility armed with an...
# 11  $GOWC Token Airdrop Worth of $10,000 NOW💵💵\n\n@GoWorldCupxyz airdrop is ready to earn. Our dearest community, this i...
# 12  It took me less than 25 minutes to set up a fake anonymous Apple ID using a VPN and disposable email, attach a maske...
# 13   JUST ANNOUNCED: Kevin McCarthy Has Said He Will Cut Social Security and Medicare If He Becomes Speaker. TELL EVERYONE!
# 14  You’ve been paying into Social Security your whole life. You earned it.\n\nNow, Republicans in Congress want to cut ...
# 15  The FBI has received credible information of a broad threat to synagogues in NJ. We ask at this time that you take a...
# 16  BREAKING EXCLUSIVE: Tens of Billions of US Dollars Were Transferred to Ukraine and then Using FTX Crypto Currency th...
# 17  💵Our Airdrop is live!\n\nParticipate in our Airdrop and earn 1 NFT for doing tasks.\n\nAirdrop: \nhttps://t.co/zEKGW...
# 18  genuinely, genuinely, do not buy twitter blue. i'm not just saying "don't give elon your money" i am saying "don't p...
# 19  FTX CEO Sam Bankman-Fried bankrolled the Democratic Party's midterms war chest to the sum of $40,000,000 using funds...
#
#                 user.id
# 0            2549754319
# 1   1191702416971968512
# 2   1346646594314244097
# 3   1143108958326054912
# 4   1143108958326054912
# 5            1640929196
# 6   1570748129846366209
# 7             462312323
# 8              36623013
# 9   1130021685351079938
# 10            918207822
# 11  1574661588023328768
# 12  1346485724997165066
# 13   812361923304034304
# 14  1349149096909668363
# 15            351907972
# 16             66019768
# 17  1567020866009206789
# 18  1349280149364236289
# 19            319139933

# %%
df[df['user.id'] == 1349149096909668363]
# Out:
#                            created_at  \
# 99482  Tue Nov 08 18:50:00 +0000 2022
# 99932  Mon Nov 07 15:30:00 +0000 2022
# 9687   Tue Nov 01 17:35:18 +0000 2022
# 53107  Thu Nov 03 17:16:57 +0000 2022
# 73534  Wed Nov 02 23:00:08 +0000 2022
# 40423  Tue Nov 15 00:30:00 +0000 2022
# 69717  Tue Nov 01 19:30:28 +0000 2022
# 65878  Sun Nov 06 21:30:00 +0000 2022
# 20982  Tue Nov 01 18:56:43 +0000 2022
# 21031  Wed Nov 02 01:50:29 +0000 2022
# 21121  Wed Nov 02 17:30:02 +0000 2022
# 81133  Mon Nov 07 21:30:31 +0000 2022
# 11828  Sat Nov 05 23:00:00 +0000 2022
# 45195  Tue Nov 01 23:56:41 +0000 2022
# 75152  Sun Nov 13 21:00:14 +0000 2022
# 75320  Sun Nov 13 19:30:02 +0000 2022
# 75588  Fri Nov 11 20:00:01 +0000 2022
#
#                                                                                                       extended_tweet.full_text  \
# 99482  I'm focused on investing in America.\n\nCongressional Republicans are focused on placing foundational programs like ...
# 99932  Congressional Republicans have embraced plans to cut Social Security and Medicare – like reducing benefits or increa...
# 9687   I’m on my way to Florida to highlight how we’re protecting Social Security and Medicare and lowering prescription dr...
# 53107  Let’s be clear about what “changes” Republicans in Congress want to make to Medicare and Social Security.\n\nThey wa...
# 73534  Social Security and Medicare are more than government programs.\n\nThey’re a promise we make. A promise that generat...
# 40423  At COP27 in Egypt, I made it clear that because of this Administration's historic climate action and work to advance...
# 69717  You’ve been paying into Social Security your whole life. You earned it.\n\nNow, Republicans in Congress want to cut ...
# 65878  Folks, there’s nothing that will create more chaos and more damage to the American economy than if Republicans in Co...
# 20982                                                                                                                      NaN
# 21031  Congressional Republicans want to cut Social Security and Medicare.\n \nThey’re even saying they’ll shut down the go...
# 21121  I believe in Social Security and Medicare.\n\nI’ve fought to protect them throughout my career.\n\nAnd I’ll keep fig...
# 81133  Social Security and Medicare have been around for a long time.\n\nGenerations of Americans have counted on these pro...
# 11828  Republican leaders are saying that if I don't help them cut Social Security and Medicare then guess what?\n \nThey w...
# 45195  Some of you are on Social Security. Or your parents or grandparents are. \n\nThey earned it with every single payche...
# 75152  I met with Prime Minister Kishida of Japan and President Yoon of the Republic of Korea. Our trilateral partnership i...
# 75320  I met with Australian Prime Minister Anthony Albanese to discuss U.S.-Australia Alliance priorities, including suppo...
# 75588  The climate crisis is about human, economic, environmental, and national security. But with innovation and cooperati...
#
#        favorite_count  \
# 99482           11849
# 99932           14682
# 9687            25220
# 53107           20179
# 73534            9903
# 40423            3466
# 69717          101204
# 65878           26148
# 20982            5140
# 21031            9164
# 21121            9424
# 81133            5735
# 11828           42616
# 45195           24545
# 75152           13702
# 75320           11494
# 75588            7966
#
#                                                                                                                      full_text  \
# 99482  I'm focused on investing in America.\n\nCongressional Republicans are focused on placing foundational programs like ...
# 99932  Congressional Republicans have embraced plans to cut Social Security and Medicare – like reducing benefits or increa...
# 9687   I’m on my way to Florida to highlight how we’re protecting Social Security and Medicare and lowering prescription dr...
# 53107  Let’s be clear about what “changes” Republicans in Congress want to make to Medicare and Social Security.\n\nThey wa...
# 73534  Social Security and Medicare are more than government programs.\n\nThey’re a promise we make. A promise that generat...
# 40423  At COP27 in Egypt, I made it clear that because of this Administration's historic climate action and work to advance...
# 69717  You’ve been paying into Social Security your whole life. You earned it.\n\nNow, Republicans in Congress want to cut ...
# 65878  Folks, there’s nothing that will create more chaos and more damage to the American economy than if Republicans in Co...
# 20982  Tune in as I deliver remarks on protecting Social Security and Medicare and lowering prescription drug costs. https:...
# 21031  Congressional Republicans want to cut Social Security and Medicare.\n \nThey’re even saying they’ll shut down the go...
# 21121  I believe in Social Security and Medicare.\n\nI’ve fought to protect them throughout my career.\n\nAnd I’ll keep fig...
# 81133  Social Security and Medicare have been around for a long time.\n\nGenerations of Americans have counted on these pro...
# 11828  Republican leaders are saying that if I don't help them cut Social Security and Medicare then guess what?\n \nThey w...
# 45195  Some of you are on Social Security. Or your parents or grandparents are. \n\nThey earned it with every single payche...
# 75152  I met with Prime Minister Kishida of Japan and President Yoon of the Republic of Korea. Our trilateral partnership i...
# 75320  I met with Australian Prime Minister Anthony Albanese to discuss U.S.-Australia Alliance priorities, including suppo...
# 75588  The climate crisis is about human, economic, environmental, and national security. But with innovation and cooperati...
#
#        geo geo.coordinates geo.type                   id  quote_count  \
# 99482  NaN             NaN      NaN  1590054044009402369          323
# 99932  NaN             NaN      NaN  1589641323077898241          509
# 9687   NaN             NaN      NaN  1587498528724623360          424
# 53107  NaN             NaN      NaN  1588218688968462337          599
# 73534  NaN             NaN      NaN  1587942665357778944          188
# 40423  NaN             NaN      NaN  1592313936359161858           14
# 69717  NaN             NaN      NaN  1587527513953415168         2253
# 65878  NaN             NaN      NaN  1589369533072015361          587
# 20982  NaN             NaN      NaN  1587519019707355136           72
# 21031  NaN             NaN      NaN  1587623147217588225          329
# 21121  NaN             NaN      NaN  1587859591437631490          230
# 81133  NaN             NaN      NaN  1589732052118953984          154
# 11828  NaN             NaN      NaN  1589029796398469122          881
# 45195  NaN             NaN      NaN  1587594509344509954          632
# 75152  NaN             NaN      NaN  1591898757775360000          106
# 75320  NaN             NaN      NaN  1591876057593831424           88
# 75588  NaN             NaN      NaN  1591158827742732288          124
#
#       quoted_status.created_at  ... truncated  \
# 99482                      NaN  ...      True
# 99932                      NaN  ...      True
# 9687                       NaN  ...      True
# 53107                      NaN  ...      True
# 73534                      NaN  ...      True
# 40423                      NaN  ...      True
# 69717                      NaN  ...      True
# 65878                      NaN  ...      True
# 20982                      NaN  ...     False
# 21031                      NaN  ...      True
# 21121                      NaN  ...      True
# 81133                      NaN  ...      True
# 11828                      NaN  ...      True
# 45195                      NaN  ...      True
# 75152                      NaN  ...      True
# 75320                      NaN  ...      True
# 75588                      NaN  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 99482                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 99932                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 9687                                NaN  Wed Jan 13 00:37:08 +0000 2021
# 53107                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 73534                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 40423                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 69717                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 65878                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 20982                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 21031                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 21121                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 81133                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 11828                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 45195                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 75152                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 75320                               NaN  Wed Jan 13 00:37:08 +0000 2021
# 75588                               NaN  Wed Jan 13 00:37:08 +0000 2021
#
#        user.followers_count  user.friends_count  user.geo_enabled  \
# 99482              27527128                  12             False
# 99932              27525621                  12             False
# 9687               27528023                  12             False
# 53107              27599836                  13             False
# 73534              27616969                  13             False
# 40423              27590042                  13             False
# 69717              27705409                  13             False
# 65878              27694906                  13             False
# 20982              27587685                  13             False
# 21031              27587678                  13             False
# 21121              27587680                  13             False
# 81133              27534074                  12             False
# 11828              27644946                  13             False
# 45195              27736345                  13             False
# 75152              27737812                  13             False
# 75320              27737808                  13             False
# 75588              27737827                  13             False
#
#                    user.id  user.location quoted_status.geo.coordinates  \
# 99482  1349149096909668363           None                           NaN
# 99932  1349149096909668363           None                           NaN
# 9687   1349149096909668363           None                           NaN
# 53107  1349149096909668363           None                           NaN
# 73534  1349149096909668363           None                           NaN
# 40423  1349149096909668363           None                           NaN
# 69717  1349149096909668363           None                           NaN
# 65878  1349149096909668363           None                           NaN
# 20982  1349149096909668363           None                           NaN
# 21031  1349149096909668363           None                           NaN
# 21121  1349149096909668363           None                           NaN
# 81133  1349149096909668363           None                           NaN
# 11828  1349149096909668363           None                           NaN
# 45195  1349149096909668363           None                           NaN
# 75152  1349149096909668363           None                           NaN
# 75320  1349149096909668363           None                           NaN
# 75588  1349149096909668363           None                           NaN
#
#        quoted_status.geo.type
# 99482                     NaN
# 99932                     NaN
# 9687                      NaN
# 53107                     NaN
# 73534                     NaN
# 40423                     NaN
# 69717                     NaN
# 65878                     NaN
# 20982                     NaN
# 21031                     NaN
# 21121                     NaN
# 81133                     NaN
# 11828                     NaN
# 45195                     NaN
# 75152                     NaN
# 75320                     NaN
# 75588                     NaN
#
# [17 rows x 39 columns]

# %%
has_reply = df[~df['quoted_status.id'].isna()]

# %%
# condition1 = ~df['user.id'].isna()
condition1 = True
condition2 = ~df['quoted_status.user.id'].isna()
has_reply = df[condition1 & condition2]

# %%
len(has_reply)
# Out:
# 3590426

# %%
df_sorted_on_quote_count = df.sort_values(by='quote_count', ascending=False)
filtered = df_sorted_on_quote_count[df_sorted_on_quote_count['quoted_status.id'].notna()]

# %%
len(filtered['quoted_status.id'])
# Out:
# 3590426

# %%
filtered.loc[:, 'quoted_status.id'] = filtered['quoted_status.id'].astype(int)
quoted_status_id_set = set(filtered['quoted_status.id'])
print(df[df['id'].isin(quoted_status_id_set)]['id'].count())
# Out:
# 110470

# %%
len(filtered['quoted_status.id'].unique())
# Out:
# 539592
